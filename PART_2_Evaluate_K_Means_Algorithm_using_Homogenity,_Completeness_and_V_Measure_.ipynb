# %% [markdown]
# <a href="https://colab.research.google.com/github/mshaffi2001/PART-2-Evaluate-K-Means-Algorithm-using-Homogenity-Completeness-and-V-Measure/blob/main/PART_2_Evaluate_K_Means_Algorithm_using_Homogenity%2C_Completeness_and_V_Measure_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score

# %%
# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data  # Features (sepal length, sepal width, petal length, petal width)
y_true = iris.target  # True labels (0: Setosa, 1: Versicolor, 2: Virginica)

# %%
# List of k values to test
k_values = [2, 3, 4]

# %%
# Loop through each k and compute metrics
for k in k_values:
    # Apply K-Means
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)  # n_init for stability
    y_pred = kmeans.fit_predict(X)

    # Compute metrics
    h = homogeneity_score(y_true, y_pred)
    c = completeness_score(y_true, y_pred)
    v = v_measure_score(y_true, y_pred)

    # Print results
    print(f"For k={k}:")
    print(f"  Homogeneity: {h:.3f}")
    print(f"  Completeness: {c:.3f}")
    print(f"  V-Measure: {v:.3f}")
    print("-" * 30)
# Out:
# For k=2:
#   Homogeneity: 0.522
#   Completeness: 0.884
#   V-Measure: 0.657
# ------------------------------
# For k=3:
#   Homogeneity: 0.751
#   Completeness: 0.765
#   V-Measure: 0.758
# ------------------------------
# For k=4:
#   Homogeneity: 0.808
#   Completeness: 0.652
#   V-Measure: 0.722
# ------------------------------
